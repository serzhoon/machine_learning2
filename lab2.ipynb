# %% [markdown]
# # Практическая работа 2. Основные конструкции языка

# %% [markdown]
# #Выполнил студент ПИН-Б-З-22-1 Гадиян Сергей Гариевич
# ## Индивидуальное задание находится внизу

# %% [markdown]
# ## Задание

# %% [markdown]
# Напишите скрипт поиска чисел, кратных 23 в списке, состоящем из элементов произвольного типа

# %% [markdown]
# ## Анализ задания, изучение возможностей языка

# %% [markdown]
# Чаще всего данные получают из файлов (работа с которыми будет рассмотрена позже). В данном рпактическом задании необходимо использовать список, определяемый программно. Список в Python - это коллекция элементов **произвольного** типа, разделенных запятыми. Объявление списка можно выполнить следующим образом:

# %%
p=[1, 4.1, 5, 6.78, 23.5, "abc", (3, 4, "Nikolaev E.I."), [5,5,5,7.67], 2+3j]
print(p)
# Out:
# [1, 4.1, 5, 6.78, 23.5, 'abc', (3, 4, 'Nikolaev E.I.'), [5, 5, 5, 7.67], (2+3j)]

# %% [markdown]
# К элементам списка можно обращаться, указывая его номер. Данная операция называется индексацией и обозначается как `[]`. Номер элемента - его индекс, указывается в квадратных скобках. При этом индексация начинается с нуля.

# %%
print('0-й элемент списка: ', p[0], type(p[0]), sep=' | ' )
print('1-й элемент списка: ', p[1], type(p[1]), sep=' | ' )
k=5
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
k=6
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
k=7
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
k=8
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
# Out:
# 0-й элемент списка:  | 1 | <class 'int'>
# 1-й элемент списка:  | 4.1 | <class 'float'>
# 5-й элемент списка:  | abc | <class 'str'>
# 6-й элемент списка:  | (3, 4, 'Nikolaev E.I.') | <class 'tuple'>
# 7-й элемент списка:  | [5, 5, 5, 7.67] | <class 'list'>
# 8-й элемент списка:  | (2+3j) | <class 'complex'>

# %% [markdown]
# Таким образом можно сделать вывод, что в Python использовать следующие типы данных: строковый (`string`), целочисленный (`int`), вещественный (`float`), комплексный (`complex`), кортежи (`tuple`), список (`list`).

# %% [markdown]
# Кроме нумерации в списках слева-направо, действует также и нумерация справа-налево, при этом крайний правый элемент имеет индекс `-1`:

# %%
k=-1
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
k=-2
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
k=-3
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
k=-100
print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-65409168> in <cell line: 0>()
#       1 k=-1
# ----> 2 print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
#       3 k=-2
#       4 print('%d-й элемент списка: ' % k, p[k], type(p[k]), sep=' | ' )
#       5 k=-3
#
# NameError: name 'p' is not defined

# %% [markdown]
# Следует обратить внимание на ошибку, возникающую в случае использования недопустимого значения индекса.

# %% [markdown]
# ## Решение задачи

# %% [markdown]
# Определим список и заполним его значениями произвольного типа:

# %%
p=["My", 33, 32, 46, 5.66, 23, [4, 6.8, "ask"], (45,67)]

# %% [markdown]
# Будем перебирать элементы списка и для каждого узнаем, делится ли он на 23 или нет. В процессе обхода будем выводить информацию о ходе решения и подсчитывать количество требуемых элементов

# %%
# переменная для хранения количества найденных элементов
K=0

# цикл для последовательного обхода элементов списка
for i in range(0, len(p)):
  e=p[i]
  if type(e)==int:
    print('%d-й элемент:' % i, 'тип: %s' % type(e), 'значение: %d' % e)
    if e%23==0:
      print('>>> делится на 23')
      K+=1
  else:
    print('%d-й элемент:' % i, 'тип: %s' % type(e))

print('Найдено элементов, кратных 23: %d' % K)
# Out:
# 0-й элемент: тип: <class 'str'>
# 1-й элемент: тип: <class 'int'> значение: 33
# 2-й элемент: тип: <class 'int'> значение: 32
# 3-й элемент: тип: <class 'int'> значение: 46
# >>> делится на 23
# 4-й элемент: тип: <class 'float'>
# 5-й элемент: тип: <class 'int'> значение: 23
# >>> делится на 23
# 6-й элемент: тип: <class 'list'>
# 7-й элемент: тип: <class 'tuple'>
# Найдено элементов, кратных 23: 2

# %% [markdown]
# В данной работе были использованы операторы `if` (условный оператор), `for ... in range(...)` (оператор цикла с обходом диапазона). Применялись функции `print()`, `type()`

# %% [markdown]
# #Индивидуальное задание
# Напишите скрипт для решения задачи в блокноте Python Notebook в
# соответствии с индивидуальным вариантом:

# %% [markdown]
# Вариант 4 <br>
# Напишите скрипт для подсчета суммы элементов целочисленного
# типа в списке, состоящем из элементов произвольного типа.

# %%
# определим список, состоящий из элементов произвольного типа
data_list = ["hello", 10, 25.5, -5, "world", 46, [1, 2], 23, (3, 4)]
sum_of_integers = 0
print("Исходный список:", data_list)
print("-" * 30)
print("Начинаем поиск и сложение целых чисел...")
print("-" * 30)
for element in data_list:
  if type(element) == int:
    print(f"Найден целочисленный элемент: {element}. Добавляем его к сумме.")
    sum_of_integers = sum_of_integers + element
  else:
     print(f"Элемент '{element}' имеет тип {type(element)} и будет пропущен.")
# итоговый результат
print("-" * 30)
print(f"Сумма всех целочисленных элементов в списке: {sum_of_integers}")
# Out:
# Исходный список: ['hello', 10, 25.5, -5, 'world', 46, [1, 2], 23, (3, 4)]
# ------------------------------
# Начинаем поиск и сложение целых чисел...
# ------------------------------
# Элемент 'hello' имеет тип <class 'str'> и будет пропущен.
# Найден целочисленный элемент: 10. Добавляем его к сумме.
# Элемент '25.5' имеет тип <class 'float'> и будет пропущен.
# Найден целочисленный элемент: -5. Добавляем его к сумме.
# Элемент 'world' имеет тип <class 'str'> и будет пропущен.
# Найден целочисленный элемент: 46. Добавляем его к сумме.
# Элемент '[1, 2]' имеет тип <class 'list'> и будет пропущен.
# Найден целочисленный элемент: 23. Добавляем его к сумме.
# Элемент '(3, 4)' имеет тип <class 'tuple'> и будет пропущен.
# ------------------------------
# Сумма всех целочисленных элементов в списке: 74

# %% [markdown]
# ##Ответы на контрольные вопросы

# %% [markdown]
# 1. Какой оператор предназначен для многократного повторения блока кода? <br>
# *Для многократного повторения блока кода в Python предназначены операторы цикла. Основных операторов цикла два:<br>
# for: Используется для перебора элементов итерируемого объекта (например, списка, кортежа, строки или диапазона range). <br>
# while: Выполняет блок кода до тех пор, пока заданное условие истинно (True)*
# 2. Перечислите операторы, применяемые в работе скрипта из учебной задачи. <br>
# *=: Оператор присваивания. Используется для присвоения значения переменной (K = 0, e = p[i]). <br>
# in: Оператор принадлежности. Используется в цикле for для последовательного перебора элементов в объекте (for i in range(...)). <br>
# []: Оператор индексации. Используется для получения доступа к элементу списка по его индексу (p[i]). <br>
# ==: Оператор равенства. Используется для сравнения двух значений (type(e) == int, e % 23 == 0). <br>
# %: Оператор взятия остатка от деления (модуль). Используется для проверки кратности числа (e % 23).<br>*
# 3. Перечислите параметры функции print( ). Опишите их назначение. <br>
#
# *Функция print() имеет несколько параметров, но чаще всего используются первые два. <br>
# print(*objects, sep=' ', end='\n', file=sys.stdout, flush=False) <br>
# **objects: Это один или несколько объектов, которые нужно вывести. Звездочка означает, что вы можете передать любое количество аргументов через запятую.
# <br>
# print("Привет", "мир") -> выводит два объекта. <br>
# sep (от separator - разделитель): Строка, которая вставляется между объектами. По умолчанию это пробел ' '. <br>
# print("яблоко", "банан", "вишня", sep=", ") -> яблоко, банан, вишня <br>
# end: Строка, которая добавляется в самом конце вывода. По умолчанию это символ переноса строки '\n', поэтому каждый вызов print() по умолчанию начинает вывод с новой строки.<br>
# print("Первая часть", end="...") <br>
# print("Вторая часть") <br>
# Вывод: Первая часть...Вторая часть <br>
# file: Объект, в который будет производиться вывод. По умолчанию это sys.stdout (стандартный вывод, т.е. консоль). Это позволяет перенаправлять вывод, например, в файл. <br>
# flush: Логическое значение. Если True, то поток вывода принудительно "сбрасывается" (информация немедленно записывается в file). Обычно это не требуется. <br>*
# 4. Что такое список в языке Python? <br>
# *Список (list) — это упорядоченная, изменяемая коллекция объектов произвольного типа.*
# 5. Объясните механизм обращения к элементам списка.<br>
# *К элементам списка обращаются по индексу, указанному в квадратных скобках [  ] после имени списка. <br>*
# Правила индексации:
#
# - Индексы начинаются с 0 (первый элемент).
#
# - Отрицательные индексы ссылаются на элементы с конца списка: -1 — последний элемент, -2 — предпоследний и т.д.
# 6. Поясните чем список отличается от массива (например в С++).<br>
# Главных отличий два:<br>
# Тип данных:<br>
# - Список может хранить элементы разных типов одновременно (числа, строки, другие списки).<br>
# - Массив хранит элементы только одного типа (например, только целые числа).<br>
# Размер:<br>
# - Список имеет динамический размер — в него можно легко добавлять и удалять элементы.<br>
# - Массив имеет фиксированный размер, который задается при его создании и не меняется.<br>
